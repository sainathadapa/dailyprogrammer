# %% [markdown]
# https://www.reddit.com/r/dailyprogrammer/comments/7i1ib1/20171206_challenge_343_intermediate_mozarts/

# %%
import numpy as np
import pandas as pd
import math

# %%
starting_composition = open('mozart-dice-starting.txt').readlines()
starting_composition = pd.DataFrame([x.rsplit() for x in starting_composition], columns = ['note', 'start', 'duration'])

# %%
starting_composition.start = pd.to_numeric(starting_composition.start)
starting_composition.duration = pd.to_numeric(starting_composition.duration)

# %%
starting_composition.head()
# Out:
#   note  start  duration
# 0   F3    0.0       1.0
# 1   F5    0.0       1.0
# 2   D3    1.0       1.0
# 3   D5    1.0       1.0
# 4   G3    2.0       1.0

# %%
starting_composition.shape
# Out:
# (1386, 3)

# %%
(starting_composition.start+starting_composition.duration).max()
# Out:
# 528.0

# %%
starting_composition.note.unique()
# Out:
# array(['F3', 'F5', 'D3', 'D5', 'G3', 'G5', 'A4', 'B2', 'F#4', 'G4', 'B4',
#        'C3', 'E3', 'C5', 'E5', 'G2', 'C6', 'C2', 'D2', 'E4', 'A5', 'F#3',
#        'F#5', 'B5', 'D6', 'D4', 'C4', 'B3', 'A3', 'C#5', 'C#3'], dtype=object)

# %%
starting_composition.duration.max()
# Out:
# 2.0

# %%
starting_composition['end'] = starting_composition.start + starting_composition.duration

# %%
starting_composition['measure'] = math.ceil(6 // 3)

# %%
starting_composition['measure'] = ((starting_composition.end - 0.001) // 3).apply(math.floor).apply(lambda x: x+1)

# %%
starting_composition
# Out:
#      note  start  duration    end  measure
# 0      F3    0.0       1.0    1.0        1
# 1      F5    0.0       1.0    1.0        1
# 2      D3    1.0       1.0    2.0        1
# 3      D5    1.0       1.0    2.0        1
# 4      G3    2.0       1.0    3.0        1
# 5      G5    2.0       1.0    3.0        1
# 6      A4    3.0       1.0    4.0        2
# 7      B2    3.0       2.0    5.0        2
# 8      G3    3.0       2.0    5.0        2
# 9     F#4    4.0       0.5    4.5        2
# 10     G4    4.5       0.5    5.0        2
# 11     B4    5.0       0.5    5.5        2
# 12     G5    5.5       0.5    6.0        2
# 13     C3    6.0       2.0    8.0        3
# 14     E3    6.0       2.0    8.0        3
# 15     G5    6.0       1.0    7.0        3
# 16     C5    7.0       1.0    8.0        3
# 17     E5    8.0       1.0    9.0        3
# 18     G2    9.0       0.5    9.5        4
# 19     G5    9.0       1.0   10.0        4
# 20     B2    9.5       0.5   10.0        4
# 21     D5   10.0       2.0   12.0        4
# 22     G3   10.0       1.0   11.0        4
# 23     B2   11.0       1.0   12.0        4
# 24     B4   12.0       2.0   14.0        5
# 25     D5   12.0       2.0   14.0        5
# 26     G2   12.0       1.0   13.0        5
# 27     G4   12.0       2.0   14.0        5
# 28     G5   12.0       2.0   14.0        5
# 29     G3   13.0       0.5   13.5        5
# ...   ...    ...       ...    ...      ...
# 1356   D5  518.5       0.5  519.0      173
# 1357   C3  519.0       0.5  519.5      174
# 1358   E3  519.0       0.5  519.5      174
# 1359   G4  519.0       1.0  520.0      174
# 1360   G3  519.5       0.5  520.0      174
# 1361   C3  520.0       0.5  520.5      174
# 1362   C5  520.0       1.0  521.0      174
# 1363   E3  520.0       0.5  520.5      174
# 1364   G3  520.5       0.5  521.0      174
# 1365   C3  521.0       0.5  521.5      174
# 1366   E3  521.0       0.5  521.5      174
# 1367   E5  521.0       1.0  522.0      174
# 1368   G3  521.5       0.5  522.0      174
# 1369   E5  522.0       0.5  522.5      175
# 1370   G3  522.0       1.0  523.0      175
# 1371   C5  522.5       0.5  523.0      175
# 1372   B4  523.0       0.5  523.5      175
# 1373   G2  523.0       1.0  524.0      175
# 1374   D5  523.5       0.5  524.0      175
# 1375   G5  524.0       1.0  525.0      175
# 1376   A5  525.0       0.5  525.5      176
# 1377   B2  525.0       2.0  527.0      176
# 1378   D3  525.0       2.0  527.0      176
# 1379   G5  525.5       0.5  526.0      176
# 1380   B5  526.0       0.5  526.5      176
# 1381   G5  526.5       0.5  527.0      176
# 1382   B2  527.0       1.0  528.0      176
# 1383   D3  527.0       1.0  528.0      176
# 1384   D5  527.0       0.5  527.5      176
# 1385   G5  527.5       0.5  528.0      176
#
# [1386 rows x 5 columns]

# %%
starting_composition[starting_composition.measure == 21]
# Out:
#     note  start  duration   end  measure
# 133   C3   60.0       1.0  61.0       21
# 134   C5   60.0       0.5  60.5       21
# 135   E5   60.5       0.5  61.0       21
# 136   D3   61.0       1.0  62.0       21
# 137   G5   61.0       0.5  61.5       21
# 138   D5   61.5       0.5  62.0       21
# 139   A4   62.0       0.5  62.5       21
# 140   D2   62.0       1.0  63.0       21
# 141  F#5   62.5       0.5  63.0       21

# %%
mozart_table = open('mozart-table.txt').readlines()
mozart_table = [x.rsplit() for x in mozart_table]
mozart_table = [[int(y) for y in x] for x in mozart_table]

# %%
mozart_table
# Out:
# [[96, 32, 69, 40, 148, 104, 152, 119, 98, 3, 54],
#  [22, 6, 95, 17, 74, 157, 60, 84, 142, 87, 130],
#  [141, 128, 158, 113, 163, 27, 171, 114, 42, 165, 10],
#  [41, 63, 13, 85, 45, 167, 53, 50, 156, 61, 103],
#  [105, 146, 153, 161, 80, 154, 99, 140, 75, 135, 28],
#  [122, 46, 55, 2, 97, 68, 133, 86, 129, 47, 37],
#  [11, 134, 110, 159, 36, 118, 21, 169, 62, 147, 106],
#  [30, 81, 24, 100, 107, 91, 127, 94, 123, 33, 5],
#  [70, 117, 66, 90, 25, 138, 16, 120, 65, 102, 35],
#  [121, 39, 136, 176, 143, 71, 155, 88, 77, 4, 20],
#  [26, 126, 15, 7, 64, 150, 57, 48, 19, 31, 108],
#  [9, 56, 132, 34, 125, 29, 175, 166, 82, 164, 92],
#  [112, 174, 73, 67, 76, 101, 43, 51, 137, 144, 12],
#  [49, 18, 58, 160, 136, 162, 168, 115, 38, 59, 124],
#  [109, 116, 145, 52, 1, 23, 89, 72, 149, 173, 44],
#  [14, 83, 79, 170, 93, 151, 172, 111, 8, 78, 131]]

# %%
import random

# %%
def compose():
    measure_list = [random.sample(x, 1)[0] for x in mozart_table]
    composition = []
    for i, x in enumerate(measure_list):
        this_measure = starting_composition[starting_composition.measure == x].copy()
        this_measure.start = this_measure.start - this_measure.start.min() + (i*3)
        composition.append(this_measure)
    composition = pd.concat(composition, ignore_index=True)
    composition.drop(['end', 'measure'], axis='columns', inplace=True)
    return composition

# %%
new_composition = compose()

# %%
new_composition
# Out:
#     note  start  duration
# 0     C3    0.0       2.0
# 1     E3    0.0       2.0
# 2     E5    0.0       0.5
# 3     C5    0.5       0.5
# 4     G5    1.0       0.5
# 5     E5    1.5       0.5
# 6     C6    2.0       0.5
# 7     G5    2.5       0.5
# 8     C3    3.0       2.0
# 9     E5    3.0       1.0
# 10    C5    4.0       1.0
# 11    G4    5.0       1.0
# 12    B2    6.0       2.0
# 13    D3    6.0       2.0
# 14    G5    6.0       0.5
# 15   F#5    6.5       0.5
# 16    G5    7.0       0.5
# 17    D5    7.5       0.5
# 18    B4    8.0       0.5
# 19    G4    8.5       0.5
# 20    C5    9.0       0.5
# 21    E3    9.0       2.0
# 22    G3    9.0       2.0
# 23    E5    9.5       0.5
# 24    C5   10.0       0.5
# 25    G4   10.5       0.5
# 26    E4   11.0       1.0
# 27    C3   12.0       2.0
# 28   F#5   12.0       1.0
# 29    A5   13.0       0.5
# ..   ...    ...       ...
# 92    C3   36.0       0.5
# 93    E3   36.0       0.5
# 94    E5   36.0       1.0
# 95    G3   36.5       0.5
# 96    C3   37.0       0.5
# 97    C5   37.0       1.0
# 98    E3   37.0       0.5
# 99    G3   37.5       0.5
# 100   C3   38.0       0.5
# 101   E3   38.0       0.5
# 102   G4   38.0       1.0
# 103   G3   38.5       0.5
# 104   C3   39.0       2.0
# 105   E3   39.0       2.0
# 106   G4   39.0       1.0
# 107   C5   40.0       1.0
# 108   C3   41.0       1.0
# 109   E5   41.0       1.0
# 110   G3   41.0       1.0
# 111   F3   42.0       2.0
# 112   F5   42.0       0.5
# 113   A5   42.5       0.5
# 114   A4   43.0       1.0
# 115   B4   44.0       0.5
# 116   G3   44.0       1.0
# 117   D5   44.5       0.5
# 118   C3   45.0       2.0
# 119   C5   45.0       1.0
# 120   C4   46.0       1.0
# 121   C2   47.0       1.0
#
# [122 rows x 3 columns]

# %%
new_composition.to_csv('new_composition.txt', sep = ' ', header=False, index=False)

# %%
from IPython.display import FileLink
FileLink('new_composition.txt')
# Out:
# /home/sainath/code/dailyprogrammer/new_composition.txt
